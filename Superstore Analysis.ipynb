# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
# 5        90032   West        Furniture  Furnishings   48.8600         7
# 6        90032   West  Office Supplies          Art    7.2800         4
# 7        90032   West       Technology       Phones  907.1520         6
# 8        90032   West  Office Supplies      Binders   18.5040         3
# 9        90032   West  Office Supplies   Appliances  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.drop(['City','Country','Postal Code'],axis=1,inplace=True)

# %%
df
# Out:
#            Ship Mode    Segment       State Region         Category  \
# 0       Second Class   Consumer    Kentucky  South        Furniture
# 1       Second Class   Consumer    Kentucky  South        Furniture
# 2       Second Class  Corporate  California   West  Office Supplies
# 3     Standard Class   Consumer     Florida  South        Furniture
# 4     Standard Class   Consumer     Florida  South  Office Supplies
# ...              ...        ...         ...    ...              ...
# 9989    Second Class   Consumer     Florida  South        Furniture
# 9990  Standard Class   Consumer  California   West        Furniture
# 9991  Standard Class   Consumer  California   West       Technology
# 9992  Standard Class   Consumer  California   West  Office Supplies
# 9993    Second Class   Consumer  California   West  Office Supplies
#
#      Sub-Category     Sales  Quantity  Discount    Profit
# 0       Bookcases  261.9600         2      0.00   41.9136
# 1          Chairs  731.9400         3      0.00  219.5820
# 2          Labels   14.6200         2      0.00    6.8714
# 3          Tables  957.5775         5      0.45 -383.0310
# 4         Storage   22.3680         2      0.20    2.5164
# ...           ...       ...       ...       ...       ...
# 9989  Furnishings   25.2480         3      0.20    4.1028
# 9990  Furnishings   91.9600         2      0.00   15.6332
# 9991       Phones  258.5760         2      0.20   19.3932
# 9992        Paper   29.6000         4      0.00   13.3200
# 9993   Appliances  243.1600         2      0.00   72.9480
#
# [9994 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# 137

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#            Ship Mode    Segment       State Region         Category  \
# 0       Second Class   Consumer    Kentucky  South        Furniture
# 1       Second Class   Consumer    Kentucky  South        Furniture
# 2       Second Class  Corporate  California   West  Office Supplies
# 3     Standard Class   Consumer     Florida  South        Furniture
# 4     Standard Class   Consumer     Florida  South  Office Supplies
# ...              ...        ...         ...    ...              ...
# 9989    Second Class   Consumer     Florida  South        Furniture
# 9990  Standard Class   Consumer  California   West        Furniture
# 9991  Standard Class   Consumer  California   West       Technology
# 9992  Standard Class   Consumer  California   West  Office Supplies
# 9993    Second Class   Consumer  California   West  Office Supplies
#
#      Sub-Category     Sales  Quantity  Discount    Profit
# 0       Bookcases  261.9600         2      0.00   41.9136
# 1          Chairs  731.9400         3      0.00  219.5820
# 2          Labels   14.6200         2      0.00    6.8714
# 3          Tables  957.5775         5      0.45 -383.0310
# 4         Storage   22.3680         2      0.20    2.5164
# ...           ...       ...       ...       ...       ...
# 9989  Furnishings   25.2480         3      0.20    4.1028
# 9990  Furnishings   91.9600         2      0.00   15.6332
# 9991       Phones  258.5760         2      0.20   19.3932
# 9992        Paper   29.6000         4      0.00   13.3200
# 9993   Appliances  243.1600         2      0.00   72.9480
#
# [9857 rows x 10 columns]

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9857.000000  9857.000000  9857.000000  9857.000000
# mean     231.802578     3.800954     0.156710    28.859913
# std      626.930390     2.233196     0.207046   235.825762
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.460000     2.000000     0.000000     1.689600
# 50%       55.480000     3.000000     0.200000     8.685500
# 75%      210.980000     5.000000     0.200000    29.692000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df.describe(include='all')
# Out:
#              Ship Mode   Segment       State Region         Category  \
# count             9857      9857        9857   9857             9857
# unique               4         3          49      4                3
# top     Standard Class  Consumer  California   West  Office Supplies
# freq              5858      5107        1934   3127             5920
# mean               NaN       NaN         NaN    NaN              NaN
# std                NaN       NaN         NaN    NaN              NaN
# min                NaN       NaN         NaN    NaN              NaN
# 25%                NaN       NaN         NaN    NaN              NaN
# 50%                NaN       NaN         NaN    NaN              NaN
# 75%                NaN       NaN         NaN    NaN              NaN
# max                NaN       NaN         NaN    NaN              NaN
#
#        Sub-Category         Sales     Quantity     Discount       Profit
# count          9857   9857.000000  9857.000000  9857.000000  9857.000000
# unique           17           NaN          NaN          NaN          NaN
# top         Binders           NaN          NaN          NaN          NaN
# freq           1512           NaN          NaN          NaN          NaN
# mean            NaN    231.802578     3.800954     0.156710    28.859913
# std             NaN    626.930390     2.233196     0.207046   235.825762
# min             NaN      0.444000     1.000000     0.000000 -6599.978000
# 25%             NaN     17.460000     2.000000     0.000000     1.689600
# 50%             NaN     55.480000     3.000000     0.200000     8.685500
# 75%             NaN    210.980000     5.000000     0.200000    29.692000
# max             NaN  22638.480000    14.000000     0.800000  8399.976000

# %%
df.sample(4)
# Out:
#          Ship Mode      Segment         State Region    Category Sub-Category  \
# 4812  Second Class     Consumer  Pennsylvania   East  Technology      Copiers
# 5660   First Class  Home Office        Oregon   West  Technology       Phones
# 2451  Second Class     Consumer      New York   East  Technology       Phones
# 7799   First Class    Corporate      New York   East   Furniture       Chairs
#
#          Sales  Quantity  Discount    Profit
# 4812  1199.976         4       0.4  179.9964
# 5660    28.680         3       0.2   -7.1700
# 2451   119.700         6       0.0   31.1220
# 7799   207.846         3       0.1    2.3094

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# State             49
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200291 -0.029292  0.479001
# Quantity  0.200291  1.000000  0.008010  0.066023
# Discount -0.029292  0.008010  1.000000 -0.220436
# Profit    0.479001  0.066023 -0.220436  1.000000

# %%
sns.heatmap(df.corr())
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df['Sales'].count()
# Out:
# 9857

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5107
# Corporate      2979
# Home Office    1771
# Name: Segment, dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'State', 'Region', 'Category', 'Sub-Category',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df['Region'].value_counts()
# Out:
# West       3127
# East       2826
# Central    2289
# South      1615
# Name: Region, dtype: int64
